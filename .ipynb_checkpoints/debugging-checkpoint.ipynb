# %%
import numpy as np


data = np.load('test_muon_0-1gev_1k.npz')

energies = data['energies']
ranges = data['ranges']
pls = data['path_lengths']
edeps = data['deposited_Es']

# %%
for i, pl in enumerate(pls):
    if ranges[i] > pl:
        print('-----------')
        print('naive longer than detailed!')
        print(f'event {i}')
        print(f'range: {ranges[i]}')
        print(f'pl: {pl}')
# Out:
# -----------
# naive longer than detailed!
# event 3
# range: 9.241631507873535
# pl: 5.130462646484375
# -----------
# naive longer than detailed!
# event 9
# range: 1124.1181640625
# pl: 1123.9345703125
# -----------
# naive longer than detailed!
# event 19
# range: 105.61058807373047
# pl: 102.99684143066406
# -----------
# naive longer than detailed!
# event 20
# range: 392.43621826171875
# pl: 391.95074462890625
# -----------
# naive longer than detailed!
# event 22
# range: 852.6738891601562
# pl: 851.2261962890625
# -----------
# naive longer than detailed!
# event 27
# range: 3.989941120147705
# pl: 0.4944744110107422
# -----------
# naive longer than detailed!
# event 34
# range: 360.77984619140625
# pl: 356.92181396484375
# -----------
# naive longer than detailed!
# event 41
# range: 4.801910877227783
# pl: 0.770209550857544
# -----------
# naive longer than detailed!
# event 47
# range: 157.32144165039062
# pl: 154.96754455566406
# -----------
# ...
